# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import wavfile
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder= r'/content/drive/MyDrive/Projects/tps/whatsapp/data/whatsapp_raw.csv'

# %%
df= pd.read_csv(folder,index_col=0)

# %%
df.head()
# Out:
#             Datetime                   Name  \
# Id
# 0   11/22/2022 19:03  Sofi⚡calidad Software
# 1   11/22/2022 19:03  Sofi⚡calidad Software
# 2   11/22/2022 19:03  Sofi⚡calidad Software
# 3   11/22/2022 19:03  Sofi⚡calidad Software
# 4   11/22/2022 19:03  Sofi⚡calidad Software
#
#                                               Message                      To
# Id
# 0   He visto que tenemos que hacer mínimo dos llam...   Sofi⚡calidad Software
# 1   He visto que tenemos que hacer mínimo dos llam...                  Robert
# 2   He visto que tenemos que hacer mínimo dos llam...  Mañas Calidad Software
# 3   He visto que tenemos que hacer mínimo dos llam...   Luna calidad Software
# 4   He visto que tenemos que hacer mínimo dos llam...   Cesar Calidad G Elias

# %%
len(df)
# Out:
# 12905

# %%
filtered_df = df[df['Name'] != df['To']]

# %%
filtered_df.head()
# Out:
#             Datetime                   Name  \
# Id
# 1   11/22/2022 19:03  Sofi⚡calidad Software
# 2   11/22/2022 19:03  Sofi⚡calidad Software
# 3   11/22/2022 19:03  Sofi⚡calidad Software
# 4   11/22/2022 19:03  Sofi⚡calidad Software
# 5   11/22/2022 19:05                 Robert
#
#                                               Message                      To
# Id
# 1   He visto que tenemos que hacer mínimo dos llam...                  Robert
# 2   He visto que tenemos que hacer mínimo dos llam...  Mañas Calidad Software
# 3   He visto que tenemos que hacer mínimo dos llam...   Luna calidad Software
# 4   He visto que tenemos que hacer mínimo dos llam...   Cesar Calidad G Elias
# 5   Me parece bien. Podemos quitarlonos del medio ...   Sofi⚡calidad Software

# %%
len(filtered_df)
# Out:
# 10468

# %%
out_file= r'/content/drive/MyDrive/Projects/tps/whatsapp/data/whatsapp_raw_well.csv'
filtered_df.to_csv(out_file)

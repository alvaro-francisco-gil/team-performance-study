# %% [markdown]
# # Individual Feature Determination

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Function Definition

# %% [markdown]
# ### Add Ratio given a column

# %%
def add_ratio_to_column(df, id_col, group_col, column, start_row):
  
    # Calculate the sum of spoken_time for each group
    group_sum = df.groupby(group_col)[column].transform('sum')

    # Calculate the spoken_time ratio
    ratio_column = column + "_ratio"
    column_index = df.columns.get_loc(column)

    # Insert the ratio_column next to the column received as a parameter
    df.insert(column_index + 1, ratio_column, np.nan)

    # Assign predefined values for the first three rows before start_row
    df.loc[start_row - 3:start_row - 1, ratio_column] = [df[column].iloc[start_row - 3],
                                                         "ratio of " + str(df[column].iloc[start_row - 2]),
                                                         "add_ratio_to_column()"]

    # Perform calculations for the ratio column from start_row onwards
    df.loc[start_row:, ratio_column] = df.loc[start_row:, column] / group_sum

    # Return the modified DataFrame
    return df

# %% [markdown]
# ### Add Ratio given a Range

# %%
def add_ratios_range(df, start_col, end_col):

  cols_range = df.columns[df.columns.get_loc(start_col):df.columns.get_loc(end_col)+1].tolist()
    
  # Loop through the emotion columns and calculate the average for each
  for col in cols_range:
      df= add_ratio_to_column(df, "ID", "group", col, 3)

  return df

# %% [markdown]
# ### Add Ratios to Features

# %%
def add_ratios_to_features(indiv_features_file, file_out):

  df= pd.read_excel(indiv_features_file)
  df= add_ratios_range(df, "indiv_spoken_time", "max_words_turn")
  df.to_csv(file_out,encoding='utf-8-sig', index=False)

  return df

# %% [markdown]
# ## Use of Function

# %%
indiv_features_file = r'/content/drive/MyDrive/Projects/tps/data/12. features/3_individual_features_final.xlsx'
file_out= r'/content/drive/MyDrive/Projects/tps/data/12. features/4_individual_features_final_ratio.xlsx'
df= pd.read_excel(indiv_features_file)

# %%
df= add_ratios_to_features(indiv_features_file, file_out)
df.head()
# Out:
#             ID            group                             shown_face  \
# 0         Type           string                                boolean
# 1  Description  id of the group  activated the camera\nat the meeting?
# 2       Script     byhand_input                           byhand_input
# 3            1                1                                  False
# 4            2                1                                  False
#
#                          indiv_spoken_time  \
# 0                                int (seg)
# 1  total speaking time\nof each individual
# 2            calc_individual_time_spoken()
# 3                                      526
# 4                                     2648
#
#                             indiv_spoken_time_ratio  \
# 0                                         int (seg)
# 1  ratio of total speaking time\nof each individual
# 2                             add_ratio_to_column()
# 3                                          0.148336
# 4                                          0.746757
#
#                   average_turn_duration  \
# 0                           float (seg)
# 1  average time of\nspoken intervention
# 2                   avg_turn_duration()
# 3                              7.850746
# 4                             33.948718
#
#                      average_turn_duration_ratio  \
# 0                                    float (seg)
# 1  ratio of average time of\nspoken intervention
# 2                          add_ratio_to_column()
# 3                                       0.126865
# 4                                       0.548598
#
#              avg_time_without_speaking  \
# 0                            int (seg)
# 1       average time without\nspeaking
# 2  max_and_avg_time_without_speaking()
# 3                            56.210746
# 4                            21.791169
#
#            avg_time_without_speaking_ratio   max_time_without_speaking  ...  \
# 0                                int (seg)                   int (seg)  ...
# 1  ratio of average time without\nspeaking  max time without\nspeaking  ...
# 2                    add_ratio_to_column()                         NaN  ...
# 3                                 0.165958                      451.54  ...
# 4                                 0.064337                      109.24  ...
#
#                  max_words_turn                   max_words_turn_ratio  \
# 0                   int (words)                            int (words)
# 1  maximum words\nused per turn  ratio of maximum words\nused per turn
# 2              max_words_turn()                  add_ratio_to_column()
# 3                            68                               0.078613
# 4                           623                               0.720231
#
#                           speech_neu                       speech_ang  \
# 0                              float                            float
# 1  average neutral\nemotion in voice  average anger\nemotion in voice
# 2                  calc_avg_emotions                              NaN
# 3                           0.832695                         0.137502
# 4                           0.795958                         0.155654
#
#                         speech_hap                     speech_sad  \
# 0                            float                          float
# 1  average happy\nemotion in voice  average sad\nemotion in voice
# 2                              NaN                            NaN
# 3                         0.026347                       0.003456
# 4                         0.045315                       0.003074
#
#                        text_joy                      text_anger  \
# 0                         float                           float
# 1  average joy\nemotion in text  average anger\nemotion in text
# 2                           NaN                             NaN
# 3                      0.298809                        0.236814
# 4                       0.29295                        0.239695
#
#                        text_fear                  text_sadness
# 0                          float                         float
# 1  average fear\nemotion in text  average sad\nemotion in text
# 2                            NaN                           NaN
# 3                       0.232361                      0.232015
# 4                       0.227768                      0.239587
#
# [5 rows x 31 columns]
